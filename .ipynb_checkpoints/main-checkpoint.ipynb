# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import math

# %% [markdown]
# # 载入图片#

# %%
img1_gray = cv2.imread("./img/1.jpg")
img2_gray = cv2.imread("./img/2.jpg")

# %% [markdown]
# # 根据匹配结果绘制特征点信息 #

# %%
def drawMatchesKnn_cv2(img1_gray,kp1,img2_gray,kp2,goodMatch):
    # 提取图像前两个维度，即长度和宽度信息，不包含颜色数据信息
    h1, w1 = img1_gray.shape[:2]
    h2, w2 = img2_gray.shape[:2]
    # 生成一张黑色大图
    vis = np.zeros((max(h1, h2), w1 + w2, 3), np.uint8)
    # 大图左边填充图1，右边填充图2
    vis[:h1, :w1] = img1_gray
    vis[:h2, w1:w1 + w2] = img2_gray
    # 取得第0张图片的p1特征点的索引和对应在第1张图片中的该特征点的索引
    p1 = [kpp.queryIdx for kpp in goodMatch]
    p2 = [kpp.trainIdx for kpp in goodMatch]
    # 将图像1中的x坐标保存到post1集合
    post1 = np.int32([kp1[pp].pt for pp in p1])
    np.save('./params/post1', post1)
    # 将图像2中的x相对于整合大图的坐标保存到post1集合
    post3 = np.int32([kp2[pp].pt for pp in p2])
    np.save('./params/post3', post3)
    # 将图像2中的x相对于图片2的坐标保存到post1集合
    post2 = post3 + (w1, 0)
    np.save('./params/post2', post2)
    # 开始连线显示坐标
    index = 0
    for (x1, y1), (x2, y2) in zip(post1, post2):
        cv2.line(vis, (x1, y1), (x2, y2), (0,0,255))
        cv2.putText(vis, str(index) + ") " + str(x1)+','+str(y1), (x1, y1), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 255, 0))
        cv2.putText(vis, str(index) + ") " + str(post3[index][0]) + ',' + str(y2), (x2, y2), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 255, 0))
        index+=1

    vis2 = vis[:,:,::-1]
    plt.figure(figsize=(20,20))
    plt.imshow(vis2)
    cv2.imwrite('./img/surf.jpg', vis2)
#     cv2.namedWindow("match",cv2.WINDOW_NORMAL)
#     cv2.imshow("match", vis)
#     plt.imshow(vis)

# %% [markdown]
# # 特征点提取 #

# %%
# 特征点提取
# sift = cv2.xfeatures2d.SIFT_create()
sift = cv2.xfeatures2d.SURF_create()

# 对两幅图像检测特征和描述符，直接找到关键点并计算
# kp为关键点列表，des为numpy的数组，为关键点数目×128
kp1, des1 = sift.detectAndCompute(img1_gray, None)
kp2, des2 = sift.detectAndCompute(img2_gray, None)

# 创建BF匹配器对象
bf = cv2.BFMatcher(cv2.NORM_L2)
# 返回k个最匹配的
matches = bf.knnMatch(des1, des2, k=2)

# 预处理匹配集合
goodMatch = []
for m, n in matches:
    # 把所获取的特征点的欧氏距离小于0.5的点加入匹配集合
    # 结果各个参数的意义如下：
    # queryIdx：测试图像的特征点描述符的下标（第几个特征点描述符），同时也是描述符对应特征点的下标。
    # trainIdx：样本图像的特征点描述符下标, 同时也是描述符对应特征点的下标。
    # distance：代表这匹配的特征点描述符的欧式距离，数值越小也就说明俩个特征点越相近。
    if m.distance < 0.50 * n.distance:
        goodMatch.append(m)

print(len(goodMatch))
# Out:
# 526

# %% [markdown]
# # 显示匹配特征点集合 #

# %%
drawMatchesKnn_cv2(img1_gray, kp1, img2_gray, kp2, goodMatch[:20])

# %% [markdown]
# # 计算深度距离 #
# *深度计算相关公式*
# ![image.png](attachment:image.png)
# *我们在前面一步中已经提取了所有的特征点并保存了其主要信息，下面我们根据这些特征点计算他们之间的视差值，然后根据上述公式，计算特征点的深度信息*

# %%
# 加载已经保存的图像匹配点信息
post1 = np.load('./params/post1.npy')
post3 = np.load('./params/post3.npy')
# 保存视差
disparity = []
# 深度计算公式
def depth(x1, x2, b, f):
    return round(abs(b*f/(x1-x2)),4)
# 开始计算深度信息
index = 0
for (x1, y1), (x2, y2) in zip(post1, post3):
    disparity.append((x1-x2, y1-y2))
    print('特征点' + str(index) + '，深度：' + str(depth(x1,x2,379/1000,707.0912)) + ' 米')
    index += 1
# Out:
# 特征点0，深度：9.241 米
# 特征点1，深度：11.6516 米
# 特征点2，深度：17.8658 米
# 特征点3，深度：16.7492 米
# 特征点4，深度：20.6144 米
# 特征点5，深度：9.241 米
# 特征点6，深度：16.7492 米
# 特征点7，深度：22.3323 米
# 特征点8，深度：29.7764 米
# 特征点9，深度：29.7764 米
# 特征点10，深度：8.6448 米
# 特征点11，深度：15.764 米
# 特征点12，深度：38.2839 米
# 特征点13，深度：33.4984 米
# 特征点14，深度：8.3746 米
# 特征点15，深度：20.6144 米
# 特征点16，深度：38.2839 米
# 特征点17，深度：8.3746 米
# 特征点18，深度：8.9329 米
# 特征点19，深度：8.9329 米
